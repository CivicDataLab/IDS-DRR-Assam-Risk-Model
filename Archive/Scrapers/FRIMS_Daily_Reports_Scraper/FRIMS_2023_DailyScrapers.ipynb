# %%
import urllib.request
import pandas as pd
import regex as re
from datetime import date, timedelta, datetime
import numpy as np
import glob

from joblib import Parallel, delayed
import multiprocessing as mp
from multiprocessing.pool import ThreadPool

import geopandas as gpd

# %%
assam_districts = gpd.read_file('Data/Assam_Maps/assam_district_35.csv')

# %% [markdown]
# # Table of Contents:
# * [Functions to be used](#functions)
# * [Download PDFs](#download)
# * [Scraper for infrastructure damage tables](#infradamages)

# %% [markdown]
# ## Functions <a class="anchor" id="functions"></a>

# %%
#Sequence Matcher helps us get the metric that measures how two strings are matching
from difflib import SequenceMatcher

#We will write a function that gives us matching score between two strings a and b. Higher the score,better the match
def similar(a, b):
    return SequenceMatcher(None, a, b).ratio()

# %%
# One FRIMS PDF has multiple tables that have to be scraped.
## The following functions are used to isolate the tables based on their categories. 
def get_table_start_index(FRIMS_DF, slug_list):
    '''
    :param FRIMS_DF: The FRIMS Data Frame of a particular date.
    :param slug_list: A list of keywords used to identify a particular table in the PDF.
    
    :return: Returns the index of the first row of the intended table.
    '''
    TABLE_START_INDEX = FRIMS_DF[FRIMS_DF.iloc[:,0].isin(slug_list)].index.values[0]
    return TABLE_START_INDEX

def get_table_end_index(FRIMS_DF, TABLE_START_INDEX):
    '''
    :param FRIMS_DF: The FRIMS Data Frame of a particular date.
    :param TABLE_START_INDEX: Once the index of a table's first row is found, it is passed into this function.
    
    :return: Returns the index of the last row of the intended table.
    '''
    for index,row in FRIMS_DF[TABLE_START_INDEX+1:].fillna('').iterrows():
        if row[0]=='':
            continue
        else:
            TABLE_END_INDEX = index
            return TABLE_END_INDEX
            break
    return TABLE_START_INDEX+100

# %%
def extract_infra_damages_data(FRIMS_DF, TABLE_START_INDEX, TABLE_END_INDEX):
    '''
    :param FRIMS_DF: The FRIMS Data Frame of a particular date.
    :param TABLE_START_INDEX: Once the index of a table's first row is found, it is passed into this function.
    :param TABLE_END_INDEX: Once the index of a table's last row is found, it is passed into this function.
    
    :return: Returns the filtered table between the indices passed, after cleaning it.
    '''
    FRIMS_INFRA_DAMAGES_DF = FRIMS_DF.loc[TABLE_START_INDEX:TABLE_END_INDEX-1,:].reset_index(drop=True)
    FRIMS_INFRA_DAMAGES_DF = FRIMS_INFRA_DAMAGES_DF.replace(r'\n','',regex=True)
    
    FRIMS_INFRA_DAMAGES_DF.columns=FRIMS_INFRA_DAMAGES_DF.iloc[0].str.replace(r'\n','',regex=True)
    FRIMS_INFRA_DAMAGES_DF = FRIMS_INFRA_DAMAGES_DF.loc[1:,:]
    
    return FRIMS_INFRA_DAMAGES_DF

# %% [markdown]
# ## Download PDFs <a class="anchor" id="download"></a>
#
# Download all PDFs from [FRIMS](http://www.asdma.gov.in/reports.html) portal

# %%
for month in range(8,9):
    if month in [8]:
        max_date=31
        min_date=1
    elif month in [7]:
        max_date=31
        min_date=1
    elif month in [8]:
        max_date=15
        min_date=1


    for day in range(min_date,max_date):
        date = str(day)+'-'+str(month)+'-'+'2024'
        if type(date)==str:
            date = datetime.strptime(date, '%d-%m-%Y').date()
        else:
            date = date + timedelta(days=-1)
        
        if date.month<10:
            date_month = '0'+str(date.month)
        else:
            date_month = str(date.month)
        
        if date.day<10:
            date_day = '0'+str(date.day)
        else:
            date_day = str(date.day)
        
        date_string = date_day+'.'+date_month+'.'+str(date.year)
        print(date_string)
        
        daily_report_url = 'https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_'+date_string+'.pdf'
    
        print(daily_report_url)
        try:

            urllib.request.urlretrieve(daily_report_url, r"DRIMS_Reports_2024/DRIMS_"+date_string+".pdf")
        except:
            print("File Not Found.")
# Out:
# 01.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_01.08.2024.pdf
# 02.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_02.08.2024.pdf
# 03.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_03.08.2024.pdf
# 04.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_04.08.2024.pdf
# 05.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_05.08.2024.pdf
# 06.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_06.08.2024.pdf
# 07.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_07.08.2024.pdf
# 08.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_08.08.2024.pdf
# 09.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_09.08.2024.pdf
# 10.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_10.08.2024.pdf
# 11.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_11.08.2024.pdf
# 12.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_12.08.2024.pdf
# 13.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_13.08.2024.pdf
# 14.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_14.08.2024.pdf
# 15.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_15.08.2024.pdf
# 16.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_16.08.2024.pdf
# 17.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_17.08.2024.pdf
# 18.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_18.08.2024.pdf
# 19.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_19.08.2024.pdf
# 20.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_20.08.2024.pdf
# 21.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_21.08.2024.pdf
# 22.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_22.08.2024.pdf
# 23.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_23.08.2024.pdf
# 24.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_24.08.2024.pdf
# 25.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_25.08.2024.pdf
# 26.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_26.08.2024.pdf
# 27.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_27.08.2024.pdf
# File Not Found.
# 28.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_28.08.2024.pdf
# File Not Found.
# 29.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_29.08.2024.pdf
# File Not Found.
# 30.08.2024
# https://www.asdma.gov.in/pdf/flood_report/2024/Daily_Flood_Report_30.08.2024.pdf
# File Not Found.

# %%
import pdfplumber
import glob
import pandas as pd

frims_pdfs = glob.glob('DRIMS_Reports_2024/*.pdf')
for pdf in frims_pdfs:
    print(pdf)
    date_string = pdf.split('DRIMS_')[-1].split('.pdf')[0]
    
    with pdfplumber.open(pdf) as pdf_file:
        tables = []
        for page in pdf_file.pages:
            tables.extend(page.extract_tables())
    
    df = pd.concat([pd.DataFrame(table) for table in tables if table], ignore_index=True)
    
    df.to_csv(f"DRIMS_Reports_2024/DRIMS_{date_string}.csv", index=False)
# Out:
# DRIMS_Reports_2024/DRIMS_18.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_21.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_02.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_01.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_19.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_05.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_18.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_29.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_20.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_02.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_15.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_12.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_01.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_16.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_05.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_02.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_19.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_23.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_08.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_11.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_16.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_10.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_22.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_06.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_07.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_11.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_15.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_07.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_08.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_16.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_09.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_04.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_21.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_24.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_09.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_26.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_18.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_28.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_10.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_13.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_26.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_14.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_17.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_17.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_04.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_06.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_22.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_20.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_24.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_05.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_27.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_25.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_03.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_03.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_10.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_06.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_19.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_20.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_12.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_27.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_08.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_23.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_01.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_26.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_23.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_04.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_09.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_07.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_11.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_25.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_13.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_21.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_22.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_13.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_15.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_14.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_25.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_12.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_29.07.2024.pdf
# DRIMS_Reports_2024/DRIMS_28.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_30.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_24.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_14.08.2024.pdf
# DRIMS_Reports_2024/DRIMS_17.06.2024.pdf
# DRIMS_Reports_2024/DRIMS_03.07.2024.pdf

# %% [markdown]
# # INFRA DAMAGES <a class="anchor" id="infradamages"></a>

# %%
import glob
import pandas as pd
dates = []
for file in glob.glob('DRIMS_Reports_2024/DRIMS_*.pdf'):
    date = file.split('DRIMS_')[-1].split('.pdf')[0]
    dates.append(date)

issue_dates = []

# %%
slug_lists = [['infrastructure damaged - road','infrastructure damaged - roads'],
              ['infrastructure damaged - embankments affected','infrastructure damaged - embankment affected'],
              ['infrastructure damaged - bridge','infrastructure damaged - bridges'],
              ['infrastructure damaged - embankments breached','infrastructure damaged - embankment breached'],
              ]

folder_slug_dict = dict()
folder_slug_dict[0] ='FRIMS_ROADS_DAMAGED'
folder_slug_dict[1] ='FRIMS_EMBANKMENTS_AFFECTED'
folder_slug_dict[2] ='FRIMS_BRIDGES_DAMAGED'
folder_slug_dict[3] ='FRIMS_EMBANKMENTS_BREACHED'

# %%
road_issue_dates = []
embankment_affected_issue_dates = []
bridge_issue_dates = []
embankment_breached_issue_dates = []

issues_dates = [road_issue_dates,
                embankment_affected_issue_dates,
               bridge_issue_dates,
                embankment_breached_issue_dates,
               ]

# %%
for date in dates:    
    print(date)
    FRIMS_csv_file = r"DRIMS_Reports_2024/DRIMS_"+date+".csv"
    
    
    FRIMS_DF = pd.read_csv(FRIMS_csv_file)
    
    FRIMS_DF.iloc[:,0] = FRIMS_DF.iloc[:,0].str.replace(r'\n','',regex=True)
    FRIMS_DF.iloc[:,0] = FRIMS_DF.iloc[:,0].str.lower()
    
    for list_number, slug_list in enumerate(slug_lists):
        folder_slug = folder_slug_dict[list_number]
        print(folder_slug)
        
        try:
            TABLE_START_INDEX = get_table_start_index(FRIMS_DF, slug_list)
        except:
            issues_dates[list_number].append(date)
            print('Issue with infra damages table - Row header across multiple pages')
            print("----")
            continue
            
        if folder_slug=='FRIMS_URBANFLOOD':
            TABLE_END_INDEX = TABLE_START_INDEX+100
        else:
            TABLE_END_INDEX = get_table_end_index(FRIMS_DF, TABLE_START_INDEX)

        if TABLE_END_INDEX-1 <= TABLE_START_INDEX:
            print("No data for: ",date)
            #done_dates.append(date)
            print("----")
            continue
        
        try:   
            FRIMS_INFRA_DAMAGES_DF = extract_infra_damages_data(FRIMS_DF, TABLE_START_INDEX, TABLE_END_INDEX-1)
        except:
            print("No dataa for: ",date)
            #issues_dates[list_number].append(date)
            print("----")
            continue
        
        try:
            col_name = FRIMS_INFRA_DAMAGES_DF.columns[1]
            FRIMS_INFRA_DAMAGES_DF[col_name] = FRIMS_INFRA_DAMAGES_DF[col_name].replace('',None).fillna(method='ffill')
            g = FRIMS_INFRA_DAMAGES_DF.groupby(col_name)['Details'].transform(lambda x: ' '.join(x))
        except:
            print('Issues with cleaning and combining')
            issues_dates[list_number].append(date)
            print("----")
            continue
            
        FRIMS_INFRA_DAMAGES_DF['Details'] = g
        FRIMS_INFRA_DAMAGES_DF_CLEANED = FRIMS_INFRA_DAMAGES_DF.drop_duplicates()
        
        
        date = date.replace('.','-')
        FRIMS_INFRA_DAMAGES_DF_CLEANED['Date'] = date
        FRIMS_INFRA_DAMAGES_DF_CLEANED = FRIMS_INFRA_DAMAGES_DF_CLEANED[['Date', col_name, 'Number', 'Details']]
        FRIMS_INFRA_DAMAGES_DF_CLEANED.columns = ['Date', 'District', 'Number', 'Details']
        FRIMS_INFRA_DAMAGES_DF_CLEANED = FRIMS_INFRA_DAMAGES_DF_CLEANED[FRIMS_INFRA_DAMAGES_DF_CLEANED['Number'].notna()]
        FRIMS_INFRA_DAMAGES_DF_CLEANED.reset_index(drop=True).to_csv(r'Data_2024/Scraped Data/'+folder_slug+r'/'+folder_slug+'_'+str(date)+'.csv', index=False)
        print('----')
# Out:
# 18.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 21.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 02.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 01.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 19.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 05.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 18.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 29.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 20.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 02.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 15.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 12.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 01.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 16.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 05.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 02.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 19.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 23.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 08.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 11.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 16.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 10.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 22.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 06.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 07.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 11.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 15.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 07.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 08.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 16.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 09.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 04.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 21.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 24.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 09.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 26.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 18.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 28.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 10.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 13.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 26.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 14.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 17.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 17.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 04.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 06.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 22.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 20.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 24.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 05.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 27.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 25.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 03.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 03.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 10.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 06.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 19.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 20.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 12.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 27.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 08.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 23.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 01.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 26.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 23.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 04.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 09.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 07.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 11.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 25.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 13.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 21.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 22.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 13.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 15.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 14.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 25.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 12.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 29.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 28.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 30.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 24.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 14.08.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 17.06.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----
# 03.07.2024
# FRIMS_ROADS_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_AFFECTED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_BRIDGES_DAMAGED
# Issue with infra damages table - Row header across multiple pages
# ----
# FRIMS_EMBANKMENTS_BREACHED
# Issue with infra damages table - Row header across multiple pages
# ----

# %%
issues_df = pd.DataFrame(issues_dates).T
issues_df.columns = folder_slug_dict.values()
issues_df

#Add this manually
# Out:
#    FRIMS_ROADS_DAMAGED FRIMS_EMBANKMENTS_AFFECTED FRIMS_BRIDGES_DAMAGED  \
# 0           18.08.2024                 18.08.2024            18.08.2024
# 1           21.08.2024                 21.08.2024            21.08.2024
# 2           02.07.2024                 02.07.2024            02.07.2024
# 3           01.08.2024                 01.08.2024            01.08.2024
# 4           19.07.2024                 19.07.2024            19.07.2024
# ..                 ...                        ...                   ...
# 80          30.06.2024                 30.06.2024            30.06.2024
# 81          24.06.2024                 24.06.2024            24.06.2024
# 82          14.08.2024                 14.08.2024            14.08.2024
# 83          17.06.2024                 17.06.2024            17.06.2024
# 84          03.07.2024                 03.07.2024            03.07.2024
#
#    FRIMS_EMBANKMENTS_BREACHED
# 0                  18.08.2024
# 1                  21.08.2024
# 2                  02.07.2024
# 3                  01.08.2024
# 4                  19.07.2024
# ..                        ...
# 80                 30.06.2024
# 81                 24.06.2024
# 82                 14.08.2024
# 83                 17.06.2024
# 84                 03.07.2024
#
# [85 rows x 4 columns]

# %%
for folder_slug in folder_slug_dict.values():
    scraped_files_daily = glob.glob(r'Data_2024/Scraped Data/{}/*.csv'.format(folder_slug))
    
    dfs = []
    for file in scraped_files_daily:
        df = pd.read_csv(file)
        dfs.append(df)
    
    FRIMS_DAMAGES = pd.concat(dfs)
    FRIMS_DAMAGES['Date'] = pd.to_datetime(FRIMS_DAMAGES['Date'],format='%d-%m-%Y')
    FRIMS_DAMAGES = FRIMS_DAMAGES.sort_values(by='Date')
    
    FRIMS_DAMAGES['District'] = FRIMS_DAMAGES.District.str.replace('Dima-Hasao','Dima Hasao',regex=True)
    FRIMS_DAMAGES['District'] = FRIMS_DAMAGES.District.str.upper()
    
    FRIMS_DAMAGES = pd.merge(FRIMS_DAMAGES,assam_districts, how='left').drop('geometry', axis=1)

    FRIMS_DAMAGES.drop_duplicates().dropna().to_csv('Data_2024/Cleaned Data/DISTRICTS_{}_MASTER_2024.csv'.format(folder_slug), index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 9
#       6     df = pd.read_csv(file)
#       7     dfs.append(df)
# ----> 9 FRIMS_DAMAGES = pd.concat(dfs)
#      10 FRIMS_DAMAGES['Date'] = pd.to_datetime(FRIMS_DAMAGES['Date'],format='%d-%m-%Y')
#      11 FRIMS_DAMAGES = FRIMS_DAMAGES.sort_values(by='Date')
#
# File ~/civicdatalab/IDS-DRR-Assam/ids-drr-assam/lib/python3.10/site-packages/pandas/core/reshape/concat.py:372, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     369 elif copy and using_copy_on_write():
#     370     copy = False
# --> 372 op = _Concatenator(
#     373     objs,
#     374     axis=axis,
#     375     ignore_index=ignore_index,
#     376     join=join,
#     377     keys=keys,
#     378     levels=levels,
#     379     names=names,
#     380     verify_integrity=verify_integrity,
#     381     copy=copy,
#     382     sort=sort,
#     383 )
#     385 return op.get_result()
#
# File ~/civicdatalab/IDS-DRR-Assam/ids-drr-assam/lib/python3.10/site-packages/pandas/core/reshape/concat.py:429, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     426     objs = list(objs)
#     428 if len(objs) == 0:
# --> 429     raise ValueError("No objects to concatenate")
#     431 if keys is None:
#     432     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate
