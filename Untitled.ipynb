# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", 50)

# %%
df = pd.read_csv('CivicDataLab_ Assam Public Procurement Data _ #not-to-be-shared - ocds_mapped_compiled.csv')
df.head()
# Out:
#                           ocid initiationType     tag  id  \
# 0   ocds-kjhdrl-2016_SAG_917_1         tender  tender   1
# 1  ocds-kjhdrl-2016_DoWR_918_1         tender  tender   1
# 2  ocds-kjhdrl-2016_DoWR_919_1         tender  tender   1
# 3  ocds-kjhdrl-2016_DoWR_920_1         tender  tender   1
# 4  ocds-kjhdrl-2016_DoWR_921_1         tender  tender   1
#
#                    date        tender/id  \
# 0  2021-12-09T10:43:59Z   2016_SAG_917_1
# 1  2021-12-09T10:43:59Z  2016_DoWR_918_1
# 2  2021-12-09T10:43:59Z  2016_DoWR_919_1
# 3  2021-12-09T10:43:59Z  2016_DoWR_920_1
# 4  2021-12-09T10:43:59Z  2016_DoWR_921_1
#
#                  tender/externalReference  \
# 0          OCSAG/09/08/LOG/2015-2016(ADM)
# 1  Re-GED/NIT/2015-16/20  Dated 5.12.2015
# 2                   Re-TWRD/G/19/VI/11/50
# 3                   Re-TWRD/G/19/VI/11/50
# 4          Re-SILWRD/E-Tender/SDRF/2016/1
#
#                                         tender/title  \
# 0  RFP For APPOINTMENT OF TRANSPORTER FOR REVERSE...
# 1                                       Kollong-pk24
# 2                                      Bamunipam-Pk9
# 3                                     Bamunipam-Pk10
# 4                                         Roypur-pk1
#
#   tender/mainProcurementCategory tender/procurementMethod  ...  \
# 0                          Works                     Open  ...
# 1                          Works                     Open  ...
# 2                          Works                     Open  ...
# 3                          Works                     Open  ...
# 4                          Works                     Open  ...
#
#   tender/tenderPeriod/durationInDays tender/allowPreferentialBidder  \
# 0                                 90                             No
# 1                                180                             No
# 2                                180                             No
# 3                                180                             No
# 4                                180                             No
#
#    Payment Mode tender/status           tender/stage  \
# 0       Offline        Active   Technical Evaluation
# 1       Offline        Active           To be Opened
# 2       Offline        Active  Technical Bid Opening
# 3       Offline        Active  Technical Bid Opening
# 4       Offline        Active  Financial Bid Opening
#
#    tender/numberOfTenderers tender/bidOpening/date     tender/milestones  \
# 0                         1    12-Apr-2016 2:00 PM  18-Apr-2016 11:15 AM
# 1                         0    11-May-2016 2:05 PM                   NaN
# 2                         1    11-May-2016 2:05 PM                   NaN
# 3                         2    11-May-2016 2:05 PM                   NaN
# 4                         1    14-May-2016 2:05 PM   16-May-2016 2:20 PM
#
#    tender/documents/id                                         buyer/name
# 0                   --             Organizing Committee-South Asian Games
# 1                   --  Department of Water Resources||Chief Engineer ...
# 2                   --  Department of Water Resources||Chief Engineer ...
# 3                   --  Department of Water Resources||Chief Engineer ...
# 4                   --  Department of Water Resources||Chief Engineer ...
#
# [5 rows x 28 columns]

# %%
df.shape
# Out:
# (30293, 28)

# %%
df.nunique()
# Out:
# ocid                                              30292
# initiationType                                        1
# tag                                                   1
# id                                                    1
# date                                                  5
# tender/id                                         30292
# tender/externalReference                          15575
# tender/title                                      25558
# tender/mainProcurementCategory                        3
# tender/procurementMethod                              5
# tender/contractType                                  15
# tender/classification/description                    86
# tender/submissionMethodDetails                        4
# tender/participationFee/0/multiCurrencyAllowed        2
# tender/allowTwoStageTender                            2
# tender/value/amount                               16982
# tender/datePublished                               8864
# tender/milestones/dueDate                          2632
# tender/tenderPeriod/durationInDays                   57
# tender/allowPreferentialBidder                        1
# Payment Mode                                          4
# tender/status                                         4
# tender/stage                                          8
# tender/numberOfTenderers                             83
# tender/bidOpening/date                             6416
# tender/milestones                                 10643
# tender/documents/id                                   1
# buyer/name                                          346
# dtype: int64

# %%
df.groupby(['tender/procurementMethod','tender/contractType'])[['ocid']].count()
#tender/procurementMethod
# Out:
#                                                ocid
# tender/procurementMethod tender/contractType
# Auction                  Item Rate                4
# Direct                   Item Rate                3
#                          Item Wise                4
#                          Lump-sum                 8
# Open                     Buy                    233
#                          EOI                    216
#                          Empanelment             53
#                          Fixed-rate               9
#                          Item Rate            17835
#                          Item Wise              762
#                          Lump-sum               824
#                          Multi-stage              6
#                          PPP-BoT-Annuity          3
#                          Percentage             377
#                          QCBS                    13
#                          Supply                2490
#                          Tender cum Auction       1
#                          Turn-key               757
#                          Works                 6378
# Open Limited             Item Rate               10
#                          Item Wise                3
#                          Supply                  43
# Selective                Buy                      2
#                          EOI                      1
#                          Empanelment              1
#                          Fixed-rate               1
#                          Item Rate              183
#                          Item Wise               11
#                          Lump-sum                17
#                          Multi-stage              1
#                          Percentage               2
#                          Supply                   6
#                          Turn-key                 7
#                          Works                   29

# %%
df[df['tender/id']=='2020_ICD_17349_1']
# Out:
#                                ocid initiationType     tag  id  \
# 23516  ocds-kjhdrl-2020_ICD_17349_1         tender  tender   1
# 30292  ocds-kjhdrl-2020_ICD_17349_1         tender  tender   1
#
#                        date         tender/id  \
# 23516  2021-12-09T10:54:02Z  2020_ICD_17349_1
# 30292  2021-12-09T10:54:02Z  2020_ICD_17349_1
#
#                tender/externalReference           tender/title  \
# 23516  AGCL/BD/PMC-GHT/PL SCADA/2019/20  PIPELINE SCADA SYSTEM
# 30292  AGCL/BD/PMC-GHT/PL SCADA/2019/20  PIPELINE SCADA SYSTEM
#
#       tender/mainProcurementCategory tender/procurementMethod  ...  \
# 23516                          Goods                     Open  ...
# 30292                          Goods                     Open  ...
#
#       tender/tenderPeriod/durationInDays tender/allowPreferentialBidder  \
# 23516                                180                             No
# 30292                                180                             No
#
#        Payment Mode tender/status           tender/stage  \
# 23516          Both        Active  Financial Bid Opening
# 30292          Both        Active  Financial Bid Opening
#
#        tender/numberOfTenderers tender/bidOpening/date     tender/milestones  \
# 23516                         2    23-Oct-2020 3:00 PM  07-Jan-2021 10:30 AM
# 30292                         2    23-Oct-2020 3:00 PM  07-Jan-2021 10:30 AM
#
#        tender/documents/id                                         buyer/name
# 23516                   --  Industries and Commerce Department||Assam Gas ...
# 30292                   --  Industries and Commerce Department||Assam Gas ...
#
# [2 rows x 28 columns]

# %%
positive_kw =  ['Flood', 'Embankment', 'embkt', 'Relief', 'Erosion', 'SDRF', 'River', 'Inundation', 'Hydrology', 'Silt', 'Siltation', 'Bund', 'Trench', 'Drain', 'Culvert', 'Sluice', 'Bridge', 'Dyke', 'Storm water drain']
positive_kw = [kw.lower() for kw in positive_kw]
negative_kw = ['Driver', 'Floodlight', 'Flood Light']
negative_kw = [kw.lower() for kw in negative_kw]

# %%
df['flood_related_bool1'] = df['tender/title'].map(lambda x: max([word.lower() in positive_kw for word in x.split()]))
df['flood_related_bool2'] = df['tender/externalReference'].map(lambda x: max([word.lower() in positive_kw for word in x.split()]))

df['not_flood_related_bool1'] = df['tender/title'].map(lambda x: max([word.lower() in negative_kw for word in x.split()]))
df['not_flood_related_bool2'] = df['tender/externalReference'].map(lambda x: max([word.lower() in negative_kw for word in x.split()]))

# %%
df['flood_related_bool']=(df['flood_related_bool1'])|(df['flood_related_bool2'])
df.drop(['flood_related_bool1','flood_related_bool2'],axis=1,inplace=True)

df['not_flood_related_bool']=(df['not_flood_related_bool1'])|(df['not_flood_related_bool2'])
df.drop(['not_flood_related_bool1','not_flood_related_bool2'],axis=1,inplace=True)

# %%
flood_df = df[(df['flood_related_bool'])&(~df['not_flood_related_bool'])]

# %%
flood_df = flood_df[['ocid','tender/title','tender/externalReference','tender/datePublished','tender/classification/description',
          'tender/mainProcurementCategory','tender/value/amount','tender/documents/id','buyer/name']]
flood_df.head()
# Out:
#                              ocid  \
# 39     ocds-kjhdrl-2016_ICD_953_1
# 44    ocds-kjhdrl-2016_GMDA_958_1
# 240   ocds-kjhdrl-2016_ICD_1190_1
# 301   ocds-kjhdrl-2016_ICD_1264_1
# 314  ocds-kjhdrl-2016_GMDA_1273_1
#
#                                           tender/title  \
# 39   TECHNICAL SURVEILLANCE OF NATURAL GAS PIPELINE...
# 44   TURNKEY DESIGN AND CONSTRUCTION OF WELL FOUNDA...
# 240                      HDD of Safrai and Deroi River
# 301  TECHNICAL SURVEILLANCE OF NATURAL GAS PIPELINE...
# 314                  Extension of Noonmati Basin Drain
#
#                           tender/externalReference tender/datePublished  \
# 39                      SC(DR)/TECH/1/84/Pt. IX/29  22-Jun-2016 9:00 AM
# 44   GMDA/GEN/7/2007/Part-VIII/59 Dated 21/06/2016  02-Jul-2016 5:00 PM
# 240             HDD/SAFRAI AND DEROI/PL/01/2014/20  08-Nov-2016 3:00 PM
# 301                      SC(DR)/TECH/1/84/Pt.IX/43  26-Nov-2016 9:00 AM
# 314                        GMDA/DEV/47/2016/Pt-1/6  06-Dec-2016 2:00 PM
#
#     tender/classification/description tender/mainProcurementCategory  \
# 39             Miscellaneous Services                       Services
# 44                        Civil Works                          Works
# 240                 Pipe Laying Works                          Works
# 301                           Oil/Gas                          Works
# 314                       Civil Works                          Works
#
#      tender/value/amount tender/documents/id  \
# 39                     0                  --
# 44             110000000                  --
# 240             14800000                  --
# 301                    0                  --
# 314            195260000                  --
#
#                                             buyer/name
# 39   Industries and Commerce Department||Assam Gas ...
# 44   Guwahati Metropolitan Development Authority||G...
# 240  Industries and Commerce Department||Assam Gas ...
# 301  Industries and Commerce Department||Assam Gas ...
# 314  Guwahati Metropolitan Development Authority||G...

# %%
pd.set_option('display.max_colwidth', None)

# %%
flood_df['tender/datePublished'] = pd.to_datetime(flood_df['tender/datePublished'])

# %%
flood_df = flood_df.set_index('tender/datePublished')

# %%
flood_df['tender/value/amount'].resample('W').sum().plot()
# Out:
# <AxesSubplot:xlabel='tender/datePublished'>

# %%
flood_df['buyer/name'].value_counts()
# Out:
# Department of Water Resources||Chief Engineer - DoWR                                                                                                                        937
# Public Works Roads Department                                                                                                                                               256
# Bodoland Territorial Council-WRD                                                                                                                                            249
# Bodoland Territorial Council||Panchayat and Rural Development-BTC                                                                                                           154
# Bodoland Territorial Council||PWD-BTC                                                                                                                                        84
# Guwahati Municipal Corporation                                                                                                                                               50
# Bodoland Territorial Council-WRD||Addl.CE cum CHD-Kokrajhar-WRD-BTC                                                                                                          32
# Industries and Commerce Department||Assam Industrial Infrastructure Development Corporation                                                                                  31
# Public Works Roads Department||CE PWD(R) - PWD                                                                                                                               26
# Industries and Commerce Department||Assam Industrial Development Corporation Ltd - ICD                                                                                       23
# Public Works Building and NH Department||Chief Engineer-Building - PWBNH                                                                                                     23
# Bodoland Territorial Council||Urban Development Town and Country Planning-BTC                                                                                                20
# Bodoland Territorial Council||Forests-BTC                                                                                                                                    20
# Guwahati Metropolitan Development Authority||Guwahati Development Department - GMDA                                                                                          16
# Public Works Roads Department||CE PWD(R) - PWD||Traffic Engineering Cell - PWD                                                                                               14
# Soil Conservation Department||Director - SCD                                                                                                                                 13
# Department of Water Resources||Flood and River Erosion Management Agency of Assam                                                                                            13
# Public Works Building and NH Department||Chief Engineer-Building - PWBNH||SE-Planning - PWBNH                                                                                12
# Assam Power Generation Company Limited                                                                                                                                       11
# Bodoland Territorial Council-PWD||Director Cum CHD - PWD BTC                                                                                                                 11
# Assam Electricity Grid Corporation Ltd||CGM (T and T)                                                                                                                        11
# Industries and Commerce Department||Assam Gas Company Ltd - ICD                                                                                                              11
# Irrigation Department||Chief Engineer(Major)-Irrigation Dept                                                                                                                  9
# Urban Development Department||Directorate of Municipality Administration - UDD||North Lakhimpur Municipal Board                                                               9
# Public Works Roads Department||CE (Border Roads and NEC Works) - PWD||NEC Roads and Bridge Cell - PWD                                                                         8
# Urban Development Department||Directorate of Town and Country Planning - UDD                                                                                                  7
# Karbi Anglong Autonomous Council||PWD||Addl. Chief Engineer Diphu                                                                                                             7
# Irrigation Department||Chief Engineer(Minor Irrigation)-Irrigation Dept                                                                                                       7
# Industries and Commerce Department||Commissioner Industries and Commerce Assam                                                                                                7
# Assam State Disaster Management Authority||Head Offcie - ASDMA                                                                                                                5
# Bodoland Territorial Council||Irrigation-BTC                                                                                                                                  5
# Director- Fire and Emergency Services-Assam                                                                                                                                   5
# Assam Inland Water Transport Development Society                                                                                                                              4
# Soil Conservation Department                                                                                                                                                  4
# Welfare of Plain Tribes and Backward Classes||Director - WPT and BC||Thengal Kachari Autonomous Council                                                                       4
# Industries and Commerce Department||Assam Petro-Chemicals Ltd.||Head office Namrup||Materials Management Department                                                           3
# Welfare of Plain Tribes and Backward Classes||Directorate of Welfare of Scheduled Caste||Assam State Development Corporation for SC                                           3
# Public Health Engineering Department||Chief Engineer PHE(P)-Assam-PHED||Lower Assam Zone-Guwahati-PHED||Guwahati Circle-Guwahati-PHED                                         3
# Pr. Chief Conservator of Forest and Head of Forest Force||Principal Chief Conservator of Forests(Wildlife and Ch. Wildlife Warden)||Mangaldai Wildlife Division, Darrang      3
# Bodoland Territorial Council||Municipal corporation-BTC                                                                                                                       3
# Irrigation Department||Chief Engineer(Minor Irrigation)-Irrigation Dept||Guwahati Project Circle (Irrigation)||Guwahati West Division (Irrigation)                            3
# Assam Police Housing Corporation Ltd                                                                                                                                          3
# Irrigation Department                                                                                                                                                         2
# Water Resources Department- World Bank Tenders||Assam Water Research and Management Institute||National Hydrology Project - SPMU                                              2
# Urban Development Department||Directorate of Municipality Administration - UDD||Chapakhowa Municipal Board                                                                    2
# Irrigation Department||Chief Engineer(Minor Irrigation)-Irrigation Dept||Dibrugarh Circle||Dibrugarh Division                                                                 2
# Public Works Building and NH Department||Chief Engineer-Building - PWBNH||SE-Guwahati Circle-2 - PWBNH                                                                        2
# Bodoland Territorial Council||Agriculture-BTC                                                                                                                                 2
# Welfare of Plain Tribes and Backward Classes||Director - WPT and BC||Sonowal Kachari Autonomous Council                                                                       1
# Public Works Building and NH Department||Chief Engineer-Building - PWBNH||SE-Tezpur Circle - PWBNH                                                                            1
# Industries and Commerce Department||DNP Limited                                                                                                                               1
# Urban Development Department||Directorate of Municipality Administration - UDD||Sorbhog Municipal Board                                                                       1
# Public Works Building and NH Department||Chief Engineer-Building - PWBNH||SE-Guwahati Circle-1 - PWBNH                                                                        1
# Industries and Commerce Department||Assam Small Industries Development Corpn. Ltd.                                                                                            1
# Urban Development Department||Directorate of Municipality Administration - UDD||Barpeta Road Municipal Board                                                                  1
# Public Works Building and NH Department||Chief Engineer-Building - PWBNH||SE-Jorhat Circle - PWBNH||EE-Jorhat Building Division - PWBNH                                       1
# Principal Secretary-Department of Information Technology||Assam Electronics Development Corporation Ltd-DoIT||Store and Purchase - AMTRON - DoIT                              1
# Welfare of Plain Tribes and Backward Classes||Director - WPT and BC||Mising Autonomous Council                                                                                1
# Urban Development Department||Assam Urban Water Supply and Sewerage Board-UDD                                                                                                 1
# Department of Tourism||Assam Tourism Development Corporation Ltd. - DOT                                                                                                       1
# Name: buyer/name, dtype: int64

# %%
flood_df.sample(5)
# Out:
#                                                ocid  \
# tender/datePublished
# 2017-07-31 10:30:00    ocds-kjhdrl-2017_BoTC_2848_1
# 2020-01-03 18:00:00   ocds-kjhdrl-2020_DoWR_15700_1
# 2020-03-14 18:00:00   ocds-kjhdrl-2020_DoWR_17162_1
# 2019-02-09 18:00:00   ocds-kjhdrl-2019_DoWR_11760_1
# 2020-11-17 15:00:00    ocds-kjhdrl-2020_PWD_19315_1
#
#                                                                                                                                                                                                                                                                     tender/title  \
# tender/datePublished
# 2017-07-31 10:30:00                                                                                                                                                                                        Construction of soil erosion protection of bundh at Katribari village
# 2020-01-03 18:00:00                                                                                                                                                        Protection of Uttar Safakamar and its adjoining area from the erosion of river Beki on its L/B (Ph-I)
# 2020-03-14 18:00:00                                                                                                                         A/E measures to protect Berajan-Rajgarh area from the flood devastation of river Jiabharali on its Right Bank under SOPD for 2019-20
# 2019-02-09 18:00:00                                                                                                                                Immediate measures to restore Rowduwar (South) area from the flood damages of river Dhansiri for the year 2018-19 (Package 5)
# 2020-11-17 15:00:00   Borkhola/SIG/III/01 Improvement of road from Kishon Nath L.P. School to Bhangarpar via Rongghar ( in stretches )including construction of RCC Bridge over river Harang Along with approaches and protection works under signature Project (Uttaran)for the
#
#                          tender/externalReference  \
# tender/datePublished
# 2017-07-31 10:30:00   DPRD/BTC/SOPD-KOJ-14/2017/2
# 2020-01-03 18:00:00    BARPETA/2019-20/SOPD-G/III
# 2020-03-14 18:00:00       TEZPUR/2019-20/SOPD-G/I
# 2019-02-09 18:00:00    JOR/SDRF/2018-19/ROWDUAR/1
# 2020-11-17 15:00:00      CE/STBR/SP/97/2019-20/10
#
#                      tender/classification/description  \
# tender/datePublished
# 2017-07-31 10:30:00                        Civil Works
# 2020-01-03 18:00:00                        Civil Works
# 2020-03-14 18:00:00                        Civil Works
# 2019-02-09 18:00:00                        Civil Works
# 2020-11-17 15:00:00                        Civil Works
#
#                      tender/mainProcurementCategory  tender/value/amount  \
# tender/datePublished
# 2017-07-31 10:30:00                           Works              2970103
# 2020-01-03 18:00:00                           Works             34653390
# 2020-03-14 18:00:00                           Works             33679124
# 2019-02-09 18:00:00                           Works               738962
# 2020-11-17 15:00:00                           Works            100000000
#
#                      tender/documents/id  \
# tender/datePublished
# 2017-07-31 10:30:00                   --
# 2020-01-03 18:00:00                   --
# 2020-03-14 18:00:00                   --
# 2019-02-09 18:00:00                   --
# 2020-11-17 15:00:00                   --
#
#                                                                              buyer/name
# tender/datePublished
# 2017-07-31 10:30:00   Bodoland Territorial Council||Panchayat and Rural Development-BTC
# 2020-01-03 18:00:00                Department of Water Resources||Chief Engineer - DoWR
# 2020-03-14 18:00:00                Department of Water Resources||Chief Engineer - DoWR
# 2019-02-09 18:00:00                Department of Water Resources||Chief Engineer - DoWR
# 2020-11-17 15:00:00                                       Public Works Roads Department

# %% [markdown]
# ## Earth Engine Data

# %%
import ee
import geemap

ee.Authenticate()
ee.Initialize()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=efzg4NPiDhUNS1KK6NURPjANKjQsVh49c7cnBG9Ljas&tc=wOVbtNLiOkyVD9JErBWxs4IDxugU0Qw26T_lah3dTy4&cc=0TUTMKezXHaa2Jtl567HBeHlERz_Esejh_1-nNzahiQ>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=efzg4NPiDhUNS1KK6NURPjANKjQsVh49c7cnBG9Ljas&tc=wOVbtNLiOkyVD9JErBWxs4IDxugU0Qw26T_lah3dTy4&cc=0TUTMKezXHaa2Jtl567HBeHlERz_Esejh_1-nNzahiQ</a></p>
#         <p>The authorization workflow will generate a code, which you
#         should paste in the box below</p>
# Enter verification code: 4/1AX4XfWgTyrIsUD_c1abtzqRsxhebogt5vHlYGlXu7aCPTQNE3D9TE40DH4E
#
# Successfully saved authorization token.

# %%
#NDVI
admin2 = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level2")
assam = admin2.filter(ee.Filter.eq('ADM1_NAME', 'Assam'))
geometry = assam.geometry()

assam_districts = ee.FeatureCollection("projects/ee-saikrishnadammalapati/assets/assam_districts");

dataset = ee.ImageCollection('COPERNICUS/S2')


#print(filtered.size())
def maskS2clouds(image):
    qa = image.select('QA60')
    cloudBitMask = 1 << 10;
    cirrusBitMask = 1 << 11;
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(qa.bitwiseAnd(cirrusBitMask).eq(0));
    
    return image.updateMask(mask).divide(10000).select("B.*").copyProperties(image, ["system:time_start"]);

def addIndices(image):
  #  ndvi = image.normalizedDifference(['B8', 'B4']).rename('ndvi');
#    ndwi = image.normalizedDifference(['B3', 'B8']).rename('ndwi');
    mndwi = image.normalizedDifference(['B3', 'B11']).rename(['mndwi']); 
#    ndti = image.normalizedDifference(['B4', 'B3']).rename(['ndti']); 
#    masked_ndti = ndti.mask(mndwi); #For NDTI - we use MNDWI as mask

    return image.addBands(mndwi);

for year in range(2017,2018):
    print(year)
    filtered = dataset.filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30)).filter(ee.Filter.date(str(year)+'-01-01', str(year)+'-02-01')).filter(ee.Filter.bounds(geometry));
    filtered = filtered.map(maskS2clouds);
    withIndices = filtered.map(addIndices);
    mndwi = withIndices.select('mndwi').toBands()
    
    #MNDWI - Assam State Level.
    geemap.zonal_statistics(mndwi, assam, str(year)+'_mndwi.csv', statistics_type='MEAN', scale=10)
# Out:
# 2017
# Computing statistics ...
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     329   try:
# --> 330     return call.execute(num_retries=num_retries)
#     331   except googleapiclient.errors.HttpError as e:
#
# ~\anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     133                     logger.warning(message)
# --> 134             return wrapped(*args, **kwargs)
#     135
#
# ~\anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     914         if resp.status >= 300:
# --> 915             raise HttpError(resp, content, uri=self.uri)
#     916         return self.postproc(resp, content)
#
# HttpError: <HttpError 400 when requesting https://earthengine.googleapis.com/v1alpha/projects/earthengine-legacy/value:compute?prettyPrint=false&alt=json returned "Computation timed out.". Details: "Computation timed out.">
#
# During handling of the above exception, another exception occurred:
#
# EEException                               Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\geemap\common.py in zonal_stats(in_value_raster, in_zone_vector, out_file_path, statistics_type, scale, crs, tile_scale, return_fc, verbose, timeout, **kwargs)
#    5581         else:
# -> 5582             ee_export_vector(result, filename, timeout=timeout)
#    5583     except Exception as e:
#
# ~\anaconda3\lib\site-packages\geemap\common.py in ee_export_vector(ee_object, filename, selectors, verbose, keep_zip, timeout)
#    1432     if selectors is None:
# -> 1433         selectors = ee_object.first().propertyNames().getInfo()
#    1434         if filetype == "csv":
#
# ~\anaconda3\lib\site-packages\ee\computedobject.py in getInfo(self)
#      97     """
# ---> 98     return data.computeValue(self)
#      99
#
# ~\anaconda3\lib\site-packages\ee\data.py in computeValue(obj)
#     734   """
# --> 735   return _execute_cloud_call(
#     736       _get_cloud_api_resource().projects().value().compute(
#
# ~\anaconda3\lib\site-packages\ee\data.py in _execute_cloud_call(call, num_retries)
#     331   except googleapiclient.errors.HttpError as e:
# --> 332     raise _translate_cloud_exception(e)
#     333
#
# EEException: Computation timed out.
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16744/1085705091.py in <module>
#      35
#      36     #MNDWI - Assam State Level.
# ---> 37     geemap.zonal_statistics(mndwi, assam, str(year)+'_mndwi.csv', statistics_type='MEAN', scale=10)
#
# ~\anaconda3\lib\site-packages\geemap\common.py in zonal_stats(in_value_raster, in_zone_vector, out_file_path, statistics_type, scale, crs, tile_scale, return_fc, verbose, timeout, **kwargs)
#    5582             ee_export_vector(result, filename, timeout=timeout)
#    5583     except Exception as e:
# -> 5584         raise Exception(e)
#    5585
#    5586
#
# Exception: Computation timed out.

# %%
for year in range(2017,2022):
    print(year)
    filtered = dataset.filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30)).filter(ee.Filter.date(str(year)+'-01-01', str(year+1)+'-04-22')).filter(ee.Filter.bounds(geometry));
    filtered = filtered.map(maskS2clouds);
    withIndices = filtered.map(addIndices);
    mndwi = withIndices.select('mndwi').toBands()
    
    #NDVI - Delhi UT Level.
    geemap.zonal_statistics(mndwi, assam_districts, str(year)+'assam_districts_mndwi.csv', statistics_type='MEAN', scale=10)

# %%
for year in range(2018,2022):
    print(year)
    filtered = dataset.filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30)).filter(ee.Filter.date(str(year)+'-01-01', str(year+1)+'-04-22')).filter(ee.Filter.bounds(geometry));
    filtered = filtered.map(maskS2clouds);
    withIndices = filtered.map(addIndices);
    ndti = withIndices.select('ndti').toBands()

    
    #NDVI - Delhi UT Level.
    geemap.zonal_statistics(ndti, delhi, str(year)+'_ndti.csv', statistics_type='MEAN', scale=10)

# %%
# Create a geometry representing an export region.
admin2 = ee.FeatureCollection("FAO/GAUL_SIMPLIFIED_500m/2015/level2")
assam = admin2.filter(ee.Filter.eq('ADM1_NAME', 'Assam'))
geometry = assam.geometry()

# %%
### THIS IS FOR RASTER EXPORTS -- NOT NEEDED.


s2 = ee.ImageCollection("COPERNICUS/S2")
rgbVis = {
  'min': 0.0,
  'max': 3000,
  'bands': ['B4', 'B3', 'B2'],
}

# Write a function for Cloud masking
def maskS2clouds(image):
    qa = image.select('QA60')
    cloudBitMask = 1 << 10
    cirrusBitMask = 1 << 11
    mask = qa.bitwiseAnd(cloudBitMask).eq(0).And(
             qa.bitwiseAnd(cirrusBitMask).eq(0))
    return image.updateMask(mask) \
      .select("B.*") \
      .copyProperties(image, ["system:time_start"])

filtered = s2 \
  .filter(ee.Filter.date('2020-01-01', '2020-01-03')) \
  .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 30)) \
  .filter(ee.Filter.bounds(geometry)) \
  .map(maskS2clouds)

# Write a function that computes NDVI for an image and adds it as a band
def add_Indices(image):
    ndvi = image.normalizedDifference(['B5', 'B4']).rename('ndvi')
    mndwi = image.normalizedDifference(['B3', 'B11']).rename('mndwi'); 
    return image.addBands(ndvi).addBands(mndwi)

withIndices = filtered.map(add_Indices)

# %%
image_ids = withIndices.aggregate_array('system:index').getInfo()
print('Total images: ', len(image_ids))
# Out:
# Total images:  1

# %%
import time

for i, image_id in enumerate(image_ids):
    image = ee.Image(withIndices.filter(ee.Filter.eq('system:index', image_id)).first())
    task = ee.batch.Export.image.toDrive(**{
        'image': image.select('mndwi'),
        'description': 'MNQWI Export {}'.format(i+1),
        'fileNamePrefix': image.id().getInfo(),
        'folder':'earthengine',
        'scale': 100,
        'region': image.geometry().bounds().getInfo()['coordinates'],
        'maxPixels': 1e10
    })
    
    task.start()

    print('Started Task: ', i+1)
    while task.active():
        print('Polling for task (id: {}).'.format(task.id))
        time.sleep(10)
# Out:
# Started Task:  1
# Polling for task (id: MU2JAARHV7CASUP3UJTH5GY6).
# Polling for task (id: MU2JAARHV7CASUP3UJTH5GY6).
# Polling for task (id: MU2JAARHV7CASUP3UJTH5GY6).

# %%
import psycopg2
conn = psycopg2.connect(database='mndwi', user='postgres',password='MyPo$tgre$ql123')
curs = conn.cursor()

# %%
#http://remote-sensing.org/managing-raster-data-with-postgis-and-python/ -- automating uploading rasters to postgis
#https://www.youtube.com/watch?v=js91cjVYRxs

# %%
from gdal import gdal
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26084/3809897516.py in <module>
# ----> 1 from gdal import gdal
#
# ModuleNotFoundError: No module named 'gdal'

# %%
pip install geopandas
# Out:
# Collecting geopandas
#   Using cached geopandas-0.10.2-py2.py3-none-any.whl (1.0 MB)
# Requirement already satisfied: pyproj>=2.2.0 in c:\users\saikr\anaconda3\lib\site-packages (from geopandas) (3.3.1)
# Requirement already satisfied: shapely>=1.6 in c:\users\saikr\anaconda3\lib\site-packages (from geopandas) (1.8.2)
# Collecting fiona>=1.8
#   Using cached Fiona-1.8.21.tar.gz (1.0 MB)
#   Using cached Fiona-1.8.20.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.19.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.18.tar.gz (1.3 MB)
# Note: you may need to restart the kernel to use updated packages.  Using cached Fiona-1.8.17.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.16.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.15.tar.gz (1.3 MB)
#   Using cached Fiona-1.8.14.tar.gz (1.3 MB)
#
#   Using cached Fiona-1.8.13.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.13.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.12.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.11.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.10.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.post1.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.9.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.8.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.7.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.6.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.5.tar.gz (1.7 MB)
#   Using cached Fiona-1.8.4.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.3.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.2.tar.gz (1.2 MB)
#   Using cached Fiona-1.8.1.tar.gz (1.1 MB)
#   Using cached Fiona-1.8.0.tar.gz (1.4 MB)
# Collecting geopandas
#   Using cached geopandas-0.10.1-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.10.0-py2.py3-none-any.whl (1.0 MB)
#   Using cached geopandas-0.9.0-py2.py3-none-any.whl (994 kB)
#   Using cached geopandas-0.8.2-py2.py3-none-any.whl (962 kB)
# Collecting fiona
#   Using cached Fiona-1.7.13.tar.gz (731 kB)
# Requirement already satisfied: pandas>=0.23.0 in c:\users\saikr\anaconda3\lib\site-packages (from geopandas) (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in c:\users\saikr\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2021.3)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\saikr\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\saikr\anaconda3\lib\site-packages (from pandas>=0.23.0->geopandas) (2.8.2)
# Requirement already satisfied: certifi in c:\users\saikr\anaconda3\lib\site-packages (from pyproj>=2.2.0->geopandas) (2021.10.8)
# Requirement already satisfied: six>=1.5 in c:\users\saikr\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.23.0->geopandas) (1.16.0)
# Requirement already satisfied: cligj>=0.4 in c:\users\saikr\anaconda3\lib\site-packages (from fiona->geopandas) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\saikr\anaconda3\lib\site-packages (from fiona->geopandas) (1.1.1)
# Requirement already satisfied: munch in c:\users\saikr\anaconda3\lib\site-packages (from fiona->geopandas) (2.5.0)
# Requirement already satisfied: click>=4.0 in c:\users\saikr\anaconda3\lib\site-packages (from cligj>=0.4->fiona->geopandas) (8.0.3)
# Requirement already satisfied: colorama in c:\users\saikr\anaconda3\lib\site-packages (from click>=4.0->cligj>=0.4->fiona->geopandas) (0.4.4)
# Building wheels for collected packages: fiona
#   Building wheel for fiona (setup.py): started
#   Building wheel for fiona (setup.py): finished with status 'error'
#   Running setup.py clean for fiona
# Failed to build fiona
# Installing collected packages: fiona, geopandas
#     Running setup.py install for fiona: started
#     Running setup.py install for fiona: finished with status 'error'
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_211d6f2ce123472cb11371619518ef6c\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_211d6f2ce123472cb11371619518ef6c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-o026mp_7'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_211d6f2ce123472cb11371619518ef6c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/67/5c/4e028e84a1f0cb3f8a994217cf2366360ca984dfc1433f6171de527d0dca/Fiona-1.8.21.tar.gz#sha256=3a0edca2a7a070db405d71187214a43d2333a57b4097544a3fcc282066a58bfc (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_5723dc8da98d4dd3b8e2ca4da91ef6ae\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_5723dc8da98d4dd3b8e2ca4da91ef6ae\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-hgcetg_q'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_5723dc8da98d4dd3b8e2ca4da91ef6ae\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ec/f7/093890341a7e8fbfcdfa04caf4dfb588ebab32c13ceaa6a3819da79ea106/Fiona-1.8.20.tar.gz#sha256=a70502d2857b82f749c09cb0dea3726787747933a2a1599b5ab787d74e3c143b (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_0daee56087044e549606e50576e01e0e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_0daee56087044e549606e50576e01e0e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-nxeskds4'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_0daee56087044e549606e50576e01e0e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a0/d9/6042aeb073d11341f7726de0586ff71c13117c34959dcf07bd4ee6d4b93e/Fiona-1.8.19.tar.gz#sha256=b9059e0b29c2e9e6b817e53f941e77e1aca7075f986005d38db307067b60458f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_28a3ea54e3bc447b89dd30159e85ee91\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_28a3ea54e3bc447b89dd30159e85ee91\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-6adrniif'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_28a3ea54e3bc447b89dd30159e85ee91\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9f/e8/401cdaa58d862a25c4b3365acf7d2bd7ac77191e3dc9acdcdac0eff20ff0/Fiona-1.8.18.tar.gz#sha256=b732ece0ff8886a29c439723a3e1fc382718804bb057519d537a81308854967a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_af58964662184c919ea34519d9e3112b\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_af58964662184c919ea34519d9e3112b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-ado4_ygi'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_af58964662184c919ea34519d9e3112b\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/88/62/69347ba2c41b526e1953c4cb66d51170b2869808863c03af202ba0121670/Fiona-1.8.17.tar.gz#sha256=716201c21246587f374785bec6d6a20a984fe1f6c2b0e83bf15127eb8f724d0c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_359cb5829d9f47fba5b356cb0f077f62\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_359cb5829d9f47fba5b356cb0f077f62\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-yuzn0tls'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_359cb5829d9f47fba5b356cb0f077f62\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/1e/60/dfc6115a11338d8aa96cacd8c60635223d9c97d61d556c90acc5dfd663fa/Fiona-1.8.16.tar.gz#sha256=fd6dfb65959becc916e9f6928618bfd59c16cdbc413ece0fbac61489cd11255f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_204c39834d8c49c28f819cb0299f9641\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_204c39834d8c49c28f819cb0299f9641\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-u__96zyq'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_204c39834d8c49c28f819cb0299f9641\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/55/2f/17450ec2c8fcc720a8a3e4d9a383499508475c7cfb90f7eca9fb585ac598/Fiona-1.8.15.tar.gz#sha256=3b1c9b5c834fae2fe947cfaea176db890bc6750d1a6ba9f54d969c19ffcd191e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_b4a0f1b7d53f49f1925b5dc3d5f8fef1\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_b4a0f1b7d53f49f1925b5dc3d5f8fef1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-06cxw940'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_b4a0f1b7d53f49f1925b5dc3d5f8fef1\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/5c/fd/5ec54f2d9b3d5dd23dd443fad5630d6b872e2664814c68b856c47e0d65af/Fiona-1.8.14.tar.gz#sha256=6eac038206c89d2cf5f99ea38b81cc228dc21eac5f47870a9a32d453b0007f4d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_d7e4ba015f1c48918fa389747b586bb4\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_d7e4ba015f1c48918fa389747b586bb4\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-1_fi6cvm'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_d7e4ba015f1c48918fa389747b586bb4\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/6d/42/f4a7cac53b28fa70e9a93d0e89a24d33e14826dad6644b699362ad84dde0/Fiona-1.8.13.post1.tar.gz#sha256=1a432bf9fd56f089256c010da009c90d4a795c531a848132c965052185336600 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_b0e16db900ef495e965c30cb5d0388bd\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_b0e16db900ef495e965c30cb5d0388bd\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-58hu9z5a'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_b0e16db900ef495e965c30cb5d0388bd\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/be/04/31d0a6f03943b1684f32c9b861be40c1fd282468fa6bd54ddf4a774e6b0f/Fiona-1.8.13.tar.gz#sha256=5ec34898c8b983a723fb4e949dd3e0ed7e691c303e51f6bfd61e52ac9ac813ae (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_af1eb5cb27fb4df680ed484519b0e86b\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_af1eb5cb27fb4df680ed484519b0e86b\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-jkdjewd2'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_af1eb5cb27fb4df680ed484519b0e86b\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/97/d8/feab39987296437fbdc3029fb39752a14355d217d73b93471010b8dd63a3/Fiona-1.8.12.tar.gz#sha256=c9266ddf6ae2a64fcea20014ddf27f800ac07584f2fdb09c2a02f3b3a52e371c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_7de43d9de33245da84a6a741bcdac04f\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_7de43d9de33245da84a6a741bcdac04f\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-ajd__67b'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_7de43d9de33245da84a6a741bcdac04f\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9d/f4/0a0ddc6174c4a93679b5f1dd3535e7ef8989828e6d5f86112de681f8c87b/Fiona-1.8.11.tar.gz#sha256=1e7ca9e051f5bffa1c43c70d573da9ca223fc076b84fa73380614fc02b9eb7f6 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_6b9b315d516844199708e2eefb11864e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_6b9b315d516844199708e2eefb11864e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-w75u69gq'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_6b9b315d516844199708e2eefb11864e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/13/73/f80b491ed8559326fab202a6d6333a3cd6e8be1e9d782bc6c0d03d476457/Fiona-1.8.10.tar.gz#sha256=ff562eb2f3960e21f8c7f050ddd7f47a763869ea14afc2234a40df72666c6a2c (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_a2cb5c2db7294328862ef6c56f39910e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_a2cb5c2db7294328862ef6c56f39910e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-2ib_zypd'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_a2cb5c2db7294328862ef6c56f39910e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/9b/52/45e75507660ce0e86176d0f59b659560f687e2c7e9ebf82a10e7dcd2d3b7/Fiona-1.8.9.post2.tar.gz#sha256=210fb038b579fab38f35ddbdd31b9725f4d5099b3edfd4b87c983e5d47b79983 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_2138cb11637743a190d3099d6d73bbfe\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_2138cb11637743a190d3099d6d73bbfe\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-myj5jvho'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_2138cb11637743a190d3099d6d73bbfe\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/0e/a4/d9dd7399be809d3990f5000fb6ae43189ea26ae88be1bed3a4c9ddc1becc/Fiona-1.8.9.post1.tar.gz#sha256=d5e0ea0b8addffe9cba4cb59e2bd495b015230e7a1b1597974f5048211930199 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_b7846a883fe84a8296d1efe7cffc50c1\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_b7846a883fe84a8296d1efe7cffc50c1\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-ffghlskx'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_b7846a883fe84a8296d1efe7cffc50c1\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ad/92/dcbd8c54d697c22f299b5af63b6df3acfbd06c6d72e249614c05be99337c/Fiona-1.8.9.tar.gz#sha256=4dd6e2f5327c1174143c7c8594a75d373bc72f2c9a2a6daee312c3186a128add (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_8efe63a9982d45dabb3512c1ec0d2a1c\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_8efe63a9982d45dabb3512c1ec0d2a1c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-hnv_cwy3'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_8efe63a9982d45dabb3512c1ec0d2a1c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/94/7f/e288db1ad63d759d494c30caae34f865e0c6927588c490705e91b7134193/Fiona-1.8.8.tar.gz#sha256=711c3be73203b37812992089445a1e4e9d3d6b64e667389f7b15406e15a91e83 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_c0b209722f4d407ab18c2c51807fd67d\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_c0b209722f4d407ab18c2c51807fd67d\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-9fz932ll'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_c0b209722f4d407ab18c2c51807fd67d\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/78/62/daafd070aebefa639df247705b97f13f7cfad43895581b5cae41bd886709/Fiona-1.8.7.tar.gz#sha256=a55a23615bad3e142d4e4cda97bb5de83c778a80049222e9dffae93c13b5cf93 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_6b0e8a6245c04045b6e6bb2e747c5946\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_6b0e8a6245c04045b6e6bb2e747c5946\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-2c5312m_'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_6b0e8a6245c04045b6e6bb2e747c5946\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/41/9d/63696e7b1de42aad294d4781199a408bec593d8fdb80a2b4a788c911a33b/Fiona-1.8.6.tar.gz#sha256=fa31dfe8855b9cd0b128b47a4df558f1b8eda90d2181bff1dd9854e5556efb3e (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_90c2aad2ac29413a8f5b4e4f3b44c606\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_90c2aad2ac29413a8f5b4e4f3b44c606\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-h5rr6_aj'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_90c2aad2ac29413a8f5b4e4f3b44c606\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7b/af/1c2c83c4a8363a4ce9fea817b1910b5e071bed012e18257faa2a0ab3cfe7/Fiona-1.8.5.tar.gz#sha256=4f5cc2d449edbbf693c83e24cdada72de7c41297383d16fcc92387eb445e9d35 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_a7dcfa55ec87415b9a2892e602ee508c\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_a7dcfa55ec87415b9a2892e602ee508c\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-dz4dvevx'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_a7dcfa55ec87415b9a2892e602ee508c\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3a/16/84960540e9fce61d767fd2f0f1d95f4c63e99ab5d8fddc308e8b51b059b8/Fiona-1.8.4.tar.gz#sha256=aec9ab2e3513c9503ec123b1a8573bee55fc6a66e2ac07088c3376bf6738a424 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_6ecd10311cd04196b16653036deb463e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_6ecd10311cd04196b16653036deb463e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-dvrpn376'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_6ecd10311cd04196b16653036deb463e\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/d1/fcdb32513a03abfde0d97fd9782ce0f8cc0540fa6c6ce783e87b94064964/Fiona-1.8.3.tar.gz#sha256=3e831100a23c3b6cd32b98baf0c9e2119d909b44a5cf4533d3625f61dcf2d2b1 (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_521f478d8f08451cb946f2ef98eb6fbc\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_521f478d8f08451cb946f2ef98eb6fbc\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-04is7j11'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_521f478d8f08451cb946f2ef98eb6fbc\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/25/50/0466d5d83e1859c5ca38351ee932d64cc5635f9d4dad522879e58f4b0018/Fiona-1.8.2.tar.gz#sha256=4c6419b7ac29136708029f6a44b4ccd458735a4d241016c7b1bab41685c08d8f (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_d997ad29dad5456c9407f1bb8196ae87\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_d997ad29dad5456c9407f1bb8196ae87\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-qop2hcc0'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_d997ad29dad5456c9407f1bb8196ae87\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/3e/5f/0c6704efeea2ff3fba7f54cc6ec38070157f21bc1cffa7bdfa7c9f6b8f7a/Fiona-1.8.1.tar.gz#sha256=4c34bb4c5cd788aaf14e5484c3b7de407b1a8a7c7b2d29bbb2e8b37931e83b8d (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_2a69676a2f194b639ee2f8b71bf00888\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_2a69676a2f194b639ee2f8b71bf00888\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\saikr\AppData\Local\Temp\pip-pip-egg-info-2a612g98'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_2a69676a2f194b639ee2f8b71bf00888\
#     Complete output (1 lines):
#     A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/2a/bd/c1efc2680f338e5941121c776d6323af6b9698ac739e22ba523cee348a7f/Fiona-1.8.0.tar.gz#sha256=20141a9ece06daa7bb4333fba640c2fe39a49f8aca5492d1da8595d41e91844a (from https://pypi.org/simple/fiona/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'C:\Users\saikr\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_014a363656e448dca7a5024257afba0e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_014a363656e448dca7a5024257afba0e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d 'C:\Users\saikr\AppData\Local\Temp\pip-wheel-emribqkk'
#        cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_014a363656e448dca7a5024257afba0e\
#   Complete output (42 lines):
#   C:\Users\saikr\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#     warnings.warn(msg)
#   C:\Users\saikr\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#     warnings.warn(msg)
#   C:\Users\saikr\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#     warnings.warn(msg)
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.9
#   creating build\lib.win-amd64-3.9\fiona
#   copying .\fiona\collection.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\compat.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\crs.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\drvsupport.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\errors.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\inspector.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\rfc3339.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\tool.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\transform.py -> build\lib.win-amd64-3.9\fiona
#   copying .\fiona\__init__.py -> build\lib.win-amd64-3.9\fiona
#   creating build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\bounds.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\calc.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\cat.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\collect.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\distrib.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\dump.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\env.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\filter.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\helpers.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\info.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\insp.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\load.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\ls.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\main.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\options.py -> build\lib.win-amd64-3.9\fiona\fio
#   copying .\fiona\fio\__init__.py -> build\lib.win-amd64-3.9\fiona\fio
#   running build_ext
#   building 'fiona._transform' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   ----------------------------------------
#   ERROR: Failed building wheel for fiona
#     ERROR: Command errored out with exit status 1:
#      command: 'C:\Users\saikr\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_014a363656e448dca7a5024257afba0e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_014a363656e448dca7a5024257afba0e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\saikr\AppData\Local\Temp\pip-record-qa6idmxn\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\saikr\anaconda3\Include\fiona'
#          cwd: C:\Users\saikr\AppData\Local\Temp\pip-install-b7fsw1w1\fiona_014a363656e448dca7a5024257afba0e\
#     Complete output (12 lines):
#     C:\Users\saikr\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'metadata_version'
#       warnings.warn(msg)
#     C:\Users\saikr\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_python'
#       warnings.warn(msg)
#     C:\Users\saikr\anaconda3\lib\distutils\dist.py:274: UserWarning: Unknown distribution option: 'requires_external'
#       warnings.warn(msg)
#     running install
#     running build
#     running build_py
#     running build_ext
#     building 'fiona._transform' extension
#     error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: 'C:\Users\saikr\anaconda3\python.exe' -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_014a363656e448dca7a5024257afba0e\\setup.py'"'"'; __file__='"'"'C:\\Users\\saikr\\AppData\\Local\\Temp\\pip-install-b7fsw1w1\\fiona_014a363656e448dca7a5024257afba0e\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record 'C:\Users\saikr\AppData\Local\Temp\pip-record-qa6idmxn\install-record.txt' --single-version-externally-managed --compile --install-headers 'C:\Users\saikr\anaconda3\Include\fiona' Check the logs for full command output.

# %%
import psycopg2
conn = psycopg2.connect(database='assamfloods_cdl',host='postgresql-assamfloods.alwaysdata.net', user='assamfloods',password='123asdf!@#')
curs = conn.cursor()

# %%
gpd.read_file('assam_districts.geojson').to_file('assam_districts.shp')

# %%
from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider

# %%
cloud_config= {
        'secure_connect_bundle': 'secure-connect-telusko.zip'
}
auth_provider = PlainTextAuthProvider('HTriMMsAyjXmghPgxSsqiSRm', '+RFjU-tPxYwMcx.aIwWdUNt+QB4,gkK61esIcrtKCYKaQ1KKNoC8stiF7w2beQO3HT4wPq61PkmU8nfEGrS_9ULHUDfO+BjuQS83hH3nv2mlm9tP-zRsT5YUCFNRC9Oa')
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect()

row = session.execute("select release_version from system.local").one()
if row:
    print(row[0])
else:
    print("An error occurred.")
# Out:
# 4.0.0.6816

# %% [markdown]
# # POSTGRES UPLOAD

# %%
import psycopg2
import os
import pandas as pd
import numpy as np
import pandas.io.sql as psql

# %%
DB_HOST = 'database-1.cbt96hk2snbv.ap-south-1.rds.amazonaws.com'
DB_NAME = 'procurements'
DB_USER = 'cdl'
DB_PASS = 'cdl@123'

# %%
conn = psycopg2.connect(dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=5432)
cursor = conn.cursor()

# %%
#Import the required file to be loaded.
df = pd.read_csv('CivicDataLab_ Assam Public Procurement Data _ #not-to-be-shared - ocds_mapped_compiled.csv')

# %%
# Schema Design:
schema_name = 'assam_procurements'
table1_name = 'tenders_static' # For fields that would be written only once.
table2_name = 'tenders_update' # For fields that would see constant updates. (tender_status etc)


# 1NF Remove Duplicates and multivalued columns (if any)
df = df.drop_duplicates(subset='ocid').reset_index(drop=True)

# Clean column headers
df.columns = [column_name.lower().replace(" ","_").replace(r'/','_') for column_name in df.columns]

df.head()
# Out:
#                           ocid initiationtype     tag  id  \
# 0   ocds-kjhdrl-2016_SAG_917_1         tender  tender   1
# 1  ocds-kjhdrl-2016_DoWR_918_1         tender  tender   1
# 2  ocds-kjhdrl-2016_DoWR_919_1         tender  tender   1
# 3  ocds-kjhdrl-2016_DoWR_920_1         tender  tender   1
# 4  ocds-kjhdrl-2016_DoWR_921_1         tender  tender   1
#
#                    date        tender_id  \
# 0  2021-12-09T10:43:59Z   2016_SAG_917_1
# 1  2021-12-09T10:43:59Z  2016_DoWR_918_1
# 2  2021-12-09T10:43:59Z  2016_DoWR_919_1
# 3  2021-12-09T10:43:59Z  2016_DoWR_920_1
# 4  2021-12-09T10:43:59Z  2016_DoWR_921_1
#
#                  tender_externalreference  \
# 0          OCSAG/09/08/LOG/2015-2016(ADM)
# 1  Re-GED/NIT/2015-16/20  Dated 5.12.2015
# 2                   Re-TWRD/G/19/VI/11/50
# 3                   Re-TWRD/G/19/VI/11/50
# 4          Re-SILWRD/E-Tender/SDRF/2016/1
#
#                                         tender_title  \
# 0  RFP For APPOINTMENT OF TRANSPORTER FOR REVERSE...
# 1                                       Kollong-pk24
# 2                                      Bamunipam-Pk9
# 3                                     Bamunipam-Pk10
# 4                                         Roypur-pk1
#
#   tender_mainprocurementcategory tender_procurementmethod  ...  \
# 0                          Works                     Open  ...
# 1                          Works                     Open  ...
# 2                          Works                     Open  ...
# 3                          Works                     Open  ...
# 4                          Works                     Open  ...
#
#   tender_tenderperiod_durationindays tender_allowpreferentialbidder  \
# 0                                 90                             No
# 1                                180                             No
# 2                                180                             No
# 3                                180                             No
# 4                                180                             No
#
#    payment_mode tender_status           tender_stage  \
# 0       Offline        Active   Technical Evaluation
# 1       Offline        Active           To be Opened
# 2       Offline        Active  Technical Bid Opening
# 3       Offline        Active  Technical Bid Opening
# 4       Offline        Active  Financial Bid Opening
#
#    tender_numberoftenderers tender_bidopening_date     tender_milestones  \
# 0                         1    12-Apr-2016 2:00 PM  18-Apr-2016 11:15 AM
# 1                         0    11-May-2016 2:05 PM                   NaN
# 2                         1    11-May-2016 2:05 PM                   NaN
# 3                         2    11-May-2016 2:05 PM                   NaN
# 4                         1    14-May-2016 2:05 PM   16-May-2016 2:20 PM
#
#    tender_documents_id                                         buyer_name
# 0                   --             Organizing Committee-South Asian Games
# 1                   --  Department of Water Resources||Chief Engineer ...
# 2                   --  Department of Water Resources||Chief Engineer ...
# 3                   --  Department of Water Resources||Chief Engineer ...
# 4                   --  Department of Water Resources||Chief Engineer ...
#
# [5 rows x 28 columns]

# %%
# Clean column types and map to POSTGRES types
df.date = pd.to_datetime(df.date)
df.tender_bidopening_date = pd.to_datetime(df.tender_bidopening_date)
df.tender_milestones = pd.to_datetime(df.tender_milestones)
df.tender_milestones_duedate = pd.to_datetime(df.tender_milestones_duedate)
df.tender_datepublished = pd.to_datetime(df.tender_datepublished)


psql_types = {'object':'varchar',
               'int64':'int',
               'datetime64[ns, UTC]': 'timestamp',
             'datetime64[ns]': 'timestamp'}

# %%
# Create Schema in DB
create_schema = '''CREATE SCHEMA IF NOT EXISTS {}'''.format(schema_name)
cursor.execute(create_schema)
conn.commit()

# %%
# Table 1 - Static
df_static = df.drop(['tender_stage','tender_status'],axis=1)
cols_table_1 = ', '.join("{} {}".format(n, d) for (n, d) in zip(df_static.columns, df_static.dtypes.astype(str).replace(psql_types)))

# %%
cursor.execute("SET search_path TO {}".format(schema_name))
create_table = '''CREATE TABLE IF NOT EXISTS {} ({}, PRIMARY KEY (ocid));'''.format(table1_name, cols_table_1)
cursor.execute(create_table)
cursor.execute('''ALTER TABLE {} ALTER COLUMN tender_value_amount TYPE numeric'''.format(table1_name))
conn.commit()

# %%
#insert values to table1
cursor.execute("SET search_path TO {}".format(schema_name))
dataframe = psql.read_sql('''SELECT ocid FROM {};'''.format(table1_name), conn)
merged = df_static.merge(dataframe,on='ocid',how='left', indicator=True)
merged = merged[merged["_merge"]=='left_only'].drop('_merge',axis=1)
merged.to_csv('data.csv',index=False,header=merged.columns,encoding='utf-8')

# Only these two should go into the static db.

data = open('data.csv')


insert = ''' COPY {} FROM STDIN WITH
            CSV
            HEADER
            DELIMITER AS ',';
            '''.format(table1_name)

cursor.copy_expert(sql=insert, file=data)
conn.commit()
print('Success!')


## If a new csv with duplicates is to be added to this table - ensure that the latest is added.
# Out:
# Success!

# %%
# Table 2 - Updates
cursor.execute("SET search_path TO {}".format(schema_name))
df_updates = df[['ocid','date','tender_stage','tender_status']]
cols_table_2 = ', '.join("{} {}".format(n, d) for (n, d) in zip(df_updates.columns, df_updates.dtypes.astype(str).replace(psql_types)))
create_table = '''CREATE TABLE IF NOT EXISTS {} ({}, FOREIGN KEY (ocid) REFERENCES {}(ocid));'''.format(table2_name, cols_table_2, table1_name)
cursor.execute(create_table)
conn.commit()

# %%
#insert values to table2
cursor.execute("SET search_path TO {}".format(schema_name))
dataframe = psql.read_sql('''SELECT ocid, date FROM {};'''.format(table2_name), conn)
dataframe['date'] = pd.to_datetime(dataframe['date'], utc = True)
merged = df_updates.merge(dataframe.head(),how='left',on=['ocid','date'],indicator=True)
merged = merged[merged['_merge']=='left_only'].drop('_merge',axis=1) 
merged.to_csv('data.csv',index=False,header=df_updates.columns,encoding='utf-8')

data = open('data.csv')

insert = ''' COPY {} FROM STDIN WITH
            CSV
            HEADER
            DELIMITER AS ',';
            '''.format(table2_name)


cursor.copy_expert(sql=insert, file=data)
conn.commit()
print('Success!')
# Out:
# Success!

# %%
cursor.execute("SET search_path TO {}".format(schema_name))
cursor.execute("DROP TABLE {}".format(table2_name))
cursor.execute("DROP TABLE {}".format(table1_name))
conn.commit()

# %%
cursor.execute("SET search_path TO {}".format(schema_name))
dataframe = psql.read_sql('''SELECT ocid, date FROM {};'''.format(table2_name), conn)

# %%
dataframe
# Out:
#                                ocid                date
# 0        ocds-kjhdrl-2016_SAG_917_1 2021-12-09 10:43:59
# 1       ocds-kjhdrl-2016_DoWR_918_1 2021-12-09 10:43:59
# 2       ocds-kjhdrl-2016_DoWR_919_1 2021-12-09 10:43:59
# 3       ocds-kjhdrl-2016_DoWR_920_1 2021-12-09 10:43:59
# 4       ocds-kjhdrl-2016_DoWR_921_1 2021-12-09 10:43:59
# ...                             ...                 ...
# 30287   ocds-kjhdrl-2021_CD_21343_2 2021-12-09 10:54:02
# 30288  ocds-kjhdrl-2021_ICD_21582_1 2021-12-09 10:54:02
# 30289  ocds-kjhdrl-2021_SSA_21583_1 2021-12-09 10:54:02
# 30290  ocds-kjhdrl-2021_SSA_21584_1 2021-12-09 10:54:02
# 30291  ocds-kjhdrl-2021_ICD_21587_1 2021-12-09 10:54:02
#
# [30292 rows x 2 columns]

# %%
data = open('data.csv')

# %%
data
# Out:
# <_io.TextIOWrapper name='data.csv' mode='r' encoding='cp1252'>

# %%
data.close()

# %%
data
# Out:
# <_io.TextIOWrapper name='data.csv' mode='r' encoding='cp1252'>

# %%
merged.to_csv('data.csv',index=False,header=df_updates.columns,encoding='utf-8')

# %%
AWS_ACCESS_KEY_ID = 'AKIAU4AADMBMHJCSPPHE'
AWS_SECRET_ACCESS_KEY = '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'

# %%
import boto3

s3 = boto3.resource(
        service_name='s3',
        region_name='ap-south-1',
        aws_access_key_id=AWS_ACCESS_KEY_ID,
        aws_secret_access_key=AWS_SECRET_ACCESS_KEY
    )

# %%
g ='CivicDataLab_ Assam Public Procurement Data _ #not-to-be-shared - ocds_mapped_compiled.csv'
if g in [i.key for i in s3.Bucket('assamtenders').objects.all()]:
    g = g.split('.csv')[0]+str(1)+'.csv'

# %%
cols_table_1
# Out:
# 'ocid varchar, initiationtype varchar, tag varchar, id int, date timestamp, tender_id varchar, tender_externalreference varchar, tender_title varchar, tender_mainprocurementcategory varchar, tender_procurementmethod varchar, tender_contracttype varchar, tender_classification_description varchar, tender_submissionmethoddetails int, tender_participationfee_0_multicurrencyallowed varchar, tender_allowtwostagetender varchar, tender_value_amount int, tender_datepublished timestamp, tender_milestones_duedate timestamp, tender_tenderperiod_durationindays int, tender_allowpreferentialbidder varchar, payment_mode varchar, tender_numberoftenderers int, tender_bidopening_date timestamp, tender_milestones timestamp, tender_documents_id varchar, buyer_name varchar'

# %%
c =[1,2,3]
d = [1,3,2]

# %%
set(c)==set(d)
# Out:
# True

# %%
river_df = flood_df[(flood_df['tender/title'].str.contains('River'))|(flood_df['tender/title'].str.contains('river'))]

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen
url = 'https://en.wikipedia.org/wiki/List_of_rivers_of_Assam'
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')

# %%
parent = soup.find_all("ul")

# %%
assam_rivers = []
for ultag in parent[1:3]:
    for litag in ultag.find_all('li'):
        assam_rivers.append(litag.text.split('River')[0].strip().lower())

# %%
conn = psycopg2.connect(dbname=DB_NAME, user=DB_USER, password=DB_PASS, host=DB_HOST, port=5432)
cursor = conn.cursor()

# %%
conn.close()

# %%
dataframeq = psql.read_sql('''SELECT * FROM assam_procurements.tender_river;''', conn)
dataframeq
# Out:
#         id                           ocid  river_id
# 0        1     ocds-kjhdrl-2016_ICD_953_1        36
# 1        2    ocds-kjhdrl-2016_GMDA_958_1        43
# 2        3    ocds-kjhdrl-2016_ICD_1190_1        12
# 3        4    ocds-kjhdrl-2016_ICD_1264_1        36
# 4        5   ocds-kjhdrl-2016_DoWR_1150_1        71
# ...    ...                            ...       ...
# 1012  1013  ocds-kjhdrl-2021_DoWR_21485_1         2
# 1013  1014  ocds-kjhdrl-2021_DoWR_21507_1       109
# 1014  1015  ocds-kjhdrl-2021_DoWR_21532_1       102
# 1015  1016  ocds-kjhdrl-2021_DoWR_21535_1       136
# 1016  1017  ocds-kjhdrl-2021_DoWR_21538_1       136
#
# [1017 rows x 3 columns]

# %%
cursor.execute("DROP TABLE assam_procurements.assam_rivers")
conn.commit()

# %%
rivers = []
for title in river_df['tender/title']:
    title = title.replace(',',' ').replace('_',' ').replace('.',' ').replace('ofriver','river').replace('Riverbank','River')
    if 'river' in title:
        idx = title.split().index('river')
        prefix = title.split()[idx-1]
        
        try:
            suffix = title.split()[idx+1]    
        except:
            pass
            
        if prefix in ['samoka']:
            river = prefix
        elif suffix in ['brahmaputra','kollong']:
            river = suffix
        elif (prefix[0].isupper())&(len(prefix)>=4):
            river = prefix
        elif (suffix[0].isupper())&(len(suffix)>=4):
            river = suffix
        else:
            river = np.NaN
            
    else:
        idx = title.split().index('River')
        prefix = title.split()[idx-1]
        try:
            suffix = title.split()[idx+1] 
        except:
            pass
            
        if prefix in ['samoka']:
            river = prefix
        elif suffix in ['brahmaputra','kollong']:
            river = suffix
        elif (prefix[0].isupper())&(len(prefix)>=4):
            river = prefix
        elif (suffix[0].isupper())&(len(suffix)>=4):
            river = suffix
        else:
            river = np.NaN
    
    rivers.append(river)

# %%
river_df
# Out:
#                                 ocid  \
# 240      ocds-kjhdrl-2016_ICD_1190_1
# 342     ocds-kjhdrl-2016_DoWR_1150_1
# 358     ocds-kjhdrl-2016_DoWR_1310_1
# 359     ocds-kjhdrl-2016_DoWR_1311_1
# 483     ocds-kjhdrl-2016_DoWR_1423_1
# ...                              ...
# 30176  ocds-kjhdrl-2021_DoWR_21485_1
# 30228  ocds-kjhdrl-2021_DoWR_21507_1
# 30237  ocds-kjhdrl-2021_DoWR_21532_1
# 30238  ocds-kjhdrl-2021_DoWR_21535_1
# 30239  ocds-kjhdrl-2021_DoWR_21538_1
#
#                                             tender/title  \
# 240                        HDD of Safrai and Deroi River
# 342                                     IM river Tingrai
# 358                                   IM at River Singra
# 359                      IM for Sumdiri River Right Bank
# 483                                  I.M river Belsiri-2
# ...                                                  ...
# 30176  I/M to restore flood damages by river Dibru al...
# 30228  A/E measures to protect Udaipur area (Chunpura...
# 30237  Protection of flood embankment along Kollong r...
# 30238  Repairing of Shivbari spur including stabiliza...
# 30239  Immediate Measures to restore flood damages of...
#
#                  tender/externalReference tender/datePublished  \
# 240    HDD/SAFRAI AND DEROI/PL/01/2014/20  08-Nov-2016 3:00 PM
# 342                    Dib/SDRF/2016-17/1  12-Dec-2016 6:00 PM
# 358                     NL/SDRF/2016-17/1  14-Dec-2016 6:00 PM
# 359                        2016_DoWR_1310  14-Dec-2016 6:00 PM
# 483                    Tez/SDRF/2016-17/2  27-Dec-2016 6:00 PM
# ...                                   ...                  ...
# 30176        DIB/SDRF/NOTUNGAON/2020-21/1  26-Feb-2021 9:00 AM
# 30228          DIB/RIDF/UDAIPUR/2020-21/1  26-Feb-2021 6:00 PM
# 30237           MORIGAON/2020-21/RIDF/III  26-Feb-2021 6:00 PM
# 30238            Morigaon/2020-21/RIDF/II  26-Feb-2021 6:00 PM
# 30239         DIBRUGARH /2020-21/SDRF/VII  26-Feb-2021 6:20 PM
#
#       tender/classification/description tender/mainProcurementCategory  \
# 240                   Pipe Laying Works                          Works
# 342                         Civil Works                          Works
# 358                         Civil Works                          Works
# 359                         Civil Works                          Works
# 483                         Civil Works                          Works
# ...                                 ...                            ...
# 30176                       Civil Works                          Works
# 30228                       Civil Works                          Works
# 30237                       Civil Works                          Works
# 30238                       Civil Works                          Works
# 30239                       Civil Works                          Works
#
#        tender/value/amount tender/documents/id  \
# 240               14800000                  --
# 342               12510148                  --
# 358               29818895                  --
# 359               17817979                  --
# 483               26055150                  --
# ...                    ...                 ...
# 30176             49996887                  --
# 30228             33856418                  --
# 30237             21976719                  --
# 30238             43252088                  --
# 30239             95107973                  --
#
#                                               buyer/name
# 240    Industries and Commerce Department||Assam Gas ...
# 342    Department of Water Resources||Chief Engineer ...
# 358    Department of Water Resources||Chief Engineer ...
# 359    Department of Water Resources||Chief Engineer ...
# 483    Department of Water Resources||Chief Engineer ...
# ...                                                  ...
# 30176  Department of Water Resources||Chief Engineer ...
# 30228  Department of Water Resources||Chief Engineer ...
# 30237  Department of Water Resources||Chief Engineer ...
# 30238  Department of Water Resources||Chief Engineer ...
# 30239  Department of Water Resources||Chief Engineer ...
#
# [991 rows x 9 columns]

# %%
r1 = list(set(rivers).copy()-set([np.NaN]))
r1.sort(reverse=True)
r2 = list(set(rivers).copy()-set([np.NaN]))
r2.sort()

# %%
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
fuzz.ratio('Deojara', 'Deojhara')
# Out:
# 93

# %%
len(r2)
# Out:
# 250

# %%
def remove_spelling_mistakes(r1, r2):
    for i in r1:
        scores = []
        for j in r2:
            scores.append(fuzz.ratio(i, j))
        while max(scores) == 100:
            scores[scores.index(100)] = -1

        if max(scores) >= 80:
            change = r2[scores.index(max(scores))]
            to_delete = r1[r1.index(i)]
            r1[r1.index(i)] = change
            r2[r2.index(to_delete)] = change
    return r1, r2

# %%
k = True
elbow = []
while k:
    r1,r2 = remove_spelling_mistakes(r1,r2)
    elbow.append(len(set(r2)))
    print(len(set(r2)))
    if (len(elbow)>=2):
        if (elbow[-1]==elbow[-2]):
            k=False
# Out:
# 197
# 188
# 188

# %%
set(r2)
# Out:
# {'Aai-Manas',
#  'Agrong',
#  'Along',
#  'Alpajan',
#  'Amjur',
#  'Anglishiga',
#  'Bahini',
#  'Balijan',
#  'Balti',
#  'Bank',
#  'Barak',
#  'Baralia',
#  'Barnadi',
#  'Barolia',
#  'Batiamari',
#  'Beki',
#  'Belsiri',
#  'Bettaly',
#  'Bharalu',
#  'Bharmaputra',
#  'Bhogdoi',
#  'Birinchi',
#  'Bokro',
#  'Borgang',
#  'Brahmajan',
#  'Buradia',
#  'Burhidehing',
#  'Buri',
#  'Burisuti',
#  'Chamapamati',
#  'Champa',
#  'Chamrang',
#  'Chandana',
#  'Charaipani',
#  'Charikoriah',
#  'Course',
#  'Daifam',
#  'Danga',
#  'Dansiri',
#  'Dariajuli',
#  'Dehajan',
#  'Demow',
#  'Deojara',
#  'Deopani',
#  'Deosila',
#  'Depota-1',
#  'Deroi',
#  'Desang',
#  'Dibru',
#  'Digboi',
#  'Dimly',
#  'Disam',
#  'District',
#  'Dobinjhora',
#  'Doloo',
#  'Dong',
#  'Dorni',
#  'Dudhnoi',
#  'Dulani',
#  'Dunali',
#  'Durpang',
#  'Dwijima',
#  'Erosion',
#  'Fekua',
#  'Front',
#  'Gabharu',
#  'Gagra',
#  'Gainadi',
#  'Gangadhar',
#  'Gangia',
#  'Gaon',
#  'Gaourang',
#  'Garufella',
#  'Garuphella',
#  'Gelabeel',
#  'Ghiladhari',
#  'Ghoga',
#  'Golandi',
#  'Gumrah',
#  'Guwahati',
#  'Hahkhati',
#  'Hajo',
#  'Harang',
#  'Hell',
#  'Integrated',
#  'Jakati',
#  'Jaljali',
#  'Jamuna',
#  'Janali',
#  'Janji',
#  'Jarasar',
#  'Jatinga',
#  'Jiabharali',
#  'Jinjiram',
#  'Joyma',
#  'Kakra',
#  'Kalanadi',
#  'Kalbhog',
#  'Kaldia',
#  'Kallong',
#  'Kanamakra',
#  'Kandari',
#  'Kanibhur',
#  'Karbi',
#  'Kashiguri',
#  'Katakhal',
#  'Kawadanga',
#  'Khanajan',
#  'Kharkanthi',
#  'Khawrang',
#  'Kherkotia',
#  'Killing',
#  'Knowarbari',
#  'Kolbari',
#  'Kopili',
#  'Korha',
#  'Kuki',
#  'Kulshi',
#  'Kumatiya',
#  'Kundil',
#  'Kundilnadi',
#  'Lakhimpur',
#  'Lakhmi',
#  'Lalaidang',
#  'Langkar',
#  'Laska',
#  'Longa',
#  'Lutumari',
#  'Manas',
#  'Mangaldai',
#  'Mitong',
#  'Modati',
#  'Modhura',
#  'Monai',
#  'Mora',
#  'Mora-Pagladia',
#  'Morachaulkhowa',
#  'Motonga',
#  'Nala',
#  'Nangalbhanga',
#  'Naojan',
#  'Nijla',
#  'Noa-Dehing',
#  'Noadihing',
#  'Noanadi',
#  'Nona',
#  'Pachnoi',
#  'Pagla',
#  'Pagladia',
#  'Pahumara',
#  'Pamohi',
#  'Phota',
#  'Phulaguri',
#  'Pokalagi',
#  'Puthimari',
#  'Raidak',
#  'Ramdeo',
#  'Ranganadi',
#  'Ratikhola',
#  'Rowta',
#  'Rupahi',
#  'Saktola',
#  'Sankosh',
#  'Sapkata',
#  'Sapkhaiti',
#  'Saralbhanga',
#  'Shingla',
#  'Sika',
#  'Singibeel',
#  'Singra',
#  'Sisupani',
#  'Solangi',
#  'Sonacherra',
#  'Subansiri',
#  'Suklai',
#  'Sumdiri',
#  'Swarna',
#  'Taklai',
#  'Tasobil',
#  'Tekonjhora',
#  'Telpani',
#  'Thaika',
#  'Tihu',
#  'Tingrai',
#  'Tipkai',
#  'Tipomia',
#  'Training',
#  'samoka'}

# %%
len(set(r1))
# Out:
# 188

# %%
r2[scores.index(max(scores))]
# Out:
# 'Deojara'

# %%
set(r2)
# Out:
# {'Aai-Manas',
#  'Agrong',
#  'Along',
#  'Alpajan',
#  'Amjur',
#  'Anglishiga',
#  'Bahini',
#  'Balijan',
#  'Balti',
#  'Bank',
#  'Barak',
#  'Baralia',
#  'Barnadi',
#  'Batiamari',
#  'Beki',
#  'Belsiri',
#  'Bettaly',
#  'Bharalu',
#  'Bharmaputra',
#  'Bhogdoi',
#  'Birinchi',
#  'Bokro',
#  'Borak',
#  'Borgang',
#  'Brahmajan',
#  'Buradia',
#  'Burhidehing',
#  'Buri',
#  'Burisuti',
#  'Chamapamati',
#  'Champa',
#  'Chamrang',
#  'Chandana',
#  'Charaipani',
#  'Charikoriah',
#  'Course',
#  'Daifam',
#  'Danga',
#  'Dansiri',
#  'Dariajuli',
#  'Dehajan',
#  'Demow',
#  'Deojara',
#  'Deojhora',
#  'Deopani',
#  'Deosila',
#  'Depota-1',
#  'Deroi',
#  'Desang',
#  'Dibru',
#  'Digboi',
#  'Dimly',
#  'Disam',
#  'District',
#  'Dobinjhora',
#  'Doloo',
#  'Dong',
#  'Dorni',
#  'Doyang',
#  'Dudhnoi',
#  'Dulani',
#  'Dunali',
#  'Durpang',
#  'Dwijima',
#  'Erosion',
#  'Fekua',
#  'Front',
#  'Gabharu',
#  'Gagra',
#  'Gainadi',
#  'Gangadhar',
#  'Gangia',
#  'Gaon',
#  'Gaourang',
#  'Garufella',
#  'Gelabeel',
#  'Ghiladhari',
#  'Ghoga',
#  'Golandi',
#  'Gumrah',
#  'Guwahati',
#  'Hahkhati',
#  'Hajo',
#  'Harang',
#  'Hell',
#  'Integrated',
#  'Jakati',
#  'Jaljali',
#  'Jamuna',
#  'Janali',
#  'Janji',
#  'Jarasar',
#  'Jatinga',
#  'Jiabharali',
#  'Jinjiram',
#  'Joyma',
#  'Kakra',
#  'Kalanadi',
#  'Kalbhog',
#  'Kaldia',
#  'Kallong',
#  'Kanamakra',
#  'Kandari',
#  'Kanibhur',
#  'Karbi',
#  'Kashiguri',
#  'Katakhal',
#  'Kawadanga',
#  'Khanajan',
#  'Kharkanthi',
#  'Khawrang',
#  'Kherkotia',
#  'Killing',
#  'Knowarbari',
#  'Kolbari',
#  'Kopili',
#  'Korha',
#  'Kuki',
#  'Kulshi',
#  'Kumatiya',
#  'Kumatiya-Pk2',
#  'Kundil',
#  'Kundilnadi',
#  'Lakhimpur',
#  'Lakhmi',
#  'Lalaidang',
#  'Langkar',
#  'Laska',
#  'Longa',
#  'Lutumari',
#  'Makra',
#  'Manas',
#  'Mangaldai',
#  'Mitong',
#  'Modati',
#  'Modhura',
#  'Monai',
#  'Mora',
#  'Mora-Pagladia',
#  'Morachaulkhowa',
#  'Motonga',
#  'Nala',
#  'Nangalbhanga',
#  'Naojan',
#  'Nijla',
#  'Noa-Dehing',
#  'Noadihing',
#  'Noanadi',
#  'Nona',
#  'Pachnoi',
#  'Pagla',
#  'Pagladia',
#  'Pahumara',
#  'Pamohi',
#  'Panchnai',
#  'Pekua',
#  'Phota',
#  'Phulaguri',
#  'Pokalagi',
#  'Puthimari',
#  'Raidak',
#  'Ramdeo',
#  'Ranganadi',
#  'Ratikhola',
#  'Rowta',
#  'Rupahi',
#  'Saktola',
#  'Sankosh',
#  'Sapkata',
#  'Sapkhaiti',
#  'Saralbhanga',
#  'Shingla',
#  'Sika',
#  'Singibeel',
#  'Singra',
#  'Sisupani',
#  'Solangi',
#  'Sonacherra',
#  'Sonai',
#  'Subansiri',
#  'Suklai',
#  'Sumdiri',
#  'Swarna',
#  'Taklai',
#  'Tasobil',
#  'Tekonjhora',
#  'Telpani',
#  'Thaika',
#  'Tihu',
#  'Tingrai',
#  'Tipkai',
#  'Tipomia',
#  'Training',
#  'samoka'}

# %%
r1.sort(reverse=True)

# %%
r2.index('brahmaputra')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34740/3130019997.py in <module>
# ----> 1 r2.index('brahmaputra')
#
# ValueError: 'brahmaputra' is not in list

# %%
l = [1,13,5,1]

# %%
l.remove(1)

# %%
sorted(dataframeq.river_name)
# Out:
# ['Agrong',
#  'Along',
#  'Alpajan',
#  'Amjur',
#  'Anglishiga',
#  'Bahini',
#  'Balijan',
#  'Balti',
#  'Barak',
#  'Baralia',
#  'Barnadi',
#  'Barolia',
#  'Batiamari',
#  'Beki',
#  'Belsiri',
#  'Bettaly',
#  'Bharalu',
#  'Bharmaputra',
#  'Bhogdoi',
#  'Birinchi',
#  'Bokro',
#  'Borgang',
#  'Boulder',
#  'Brahmajan',
#  'Buradia',
#  'Burhidehing',
#  'Buri',
#  'Burisuti',
#  'Chamapamati',
#  'Champa',
#  'Chamrang',
#  'Chandana',
#  'Charaipani',
#  'Charikoriah',
#  'Daifam',
#  'Danga',
#  'Dansiri',
#  'Dariajuli',
#  'Dehajan',
#  'Demow',
#  'Deojara',
#  'Deopani',
#  'Deosila',
#  'Depota',
#  'Deroi',
#  'Desang',
#  'Dibru',
#  'Digboi',
#  'Dimly',
#  'Disam',
#  'Dobinjhora',
#  'Doloo',
#  'Dong',
#  'Dorni',
#  'Dudhnoi',
#  'Dulani',
#  'Dunali',
#  'Durpang',
#  'Dwijima',
#  'Fekua',
#  'Gabharu',
#  'Gagra',
#  'Gainadi',
#  'Gangadhar',
#  'Gangia',
#  'Gaon',
#  'Gaourang',
#  'Garufella',
#  'Garuphella',
#  'Gelabeel',
#  'Ghiladhari',
#  'Ghoga',
#  'Golandi',
#  'Gumrah',
#  'Guwahati',
#  'Hahkhati',
#  'Hajo',
#  'Harang',
#  'Hell',
#  'Integrated',
#  'Jakati',
#  'Jaljali',
#  'Jamuna',
#  'Janali',
#  'Janji',
#  'Jarasar',
#  'Jatinga',
#  'Jiabharali',
#  'Jinjiram',
#  'Joyma',
#  'KOLLONG',
#  'Kakra',
#  'Kalanadi',
#  'Kalbhog',
#  'Kaldia',
#  'Kallong',
#  'Kanamakra',
#  'Kandari',
#  'Kanibhur',
#  'Karbi',
#  'Kashiguri',
#  'Katakhal',
#  'Kawadanga',
#  'Khanajan',
#  'Kharkanthi',
#  'Khawrang',
#  'Kherkotia',
#  'Killing',
#  'Knowarbari',
#  'Kolbari',
#  'Kopili',
#  'Korha',
#  'Kuki',
#  'Kulshi',
#  'Kumatiya',
#  'Kundil',
#  'Kundilnadi',
#  'Lakhimpur',
#  'Lakhmi',
#  'Lalaidang',
#  'Langkar',
#  'Laska',
#  'Longa',
#  'Lutumari',
#  'Manas',
#  'Mangaldai',
#  'Mitong',
#  'Modati',
#  'Modhura',
#  'Mora',
#  'Morachaulkhowa',
#  'Motonga',
#  'Nala',
#  'Nangalbhanga',
#  'Naojan',
#  'Nijla',
#  'Noadihing',
#  'Nona',
#  'Nonai',
#  'Pachnoi',
#  'Pagla',
#  'Pagladia',
#  'Pahumara',
#  'Pamohi',
#  'Phota',
#  'Phulaguri',
#  'Pokalagi',
#  'Puthimari',
#  'Raidak',
#  'Ramdeo',
#  'Ranganadi',
#  'Ratikhola',
#  'Rowta',
#  'Rupahi',
#  'Saktola',
#  'Sankosh',
#  'Sapkata',
#  'Sapkhaiti',
#  'Saralbhanga',
#  'Shingla',
#  'Sika',
#  'Singibeel',
#  'Singra',
#  'Sisupani',
#  'Solangi',
#  'Sonacherra',
#  'Subansiri',
#  'Suklai',
#  'Sumdiri',
#  'Swarna',
#  'Taklai',
#  'Tasobil',
#  'Tekonjhora',
#  'Telpani',
#  'Thaika',
#  'Tihu',
#  'Tingrai',
#  'Tipkai',
#  'Tipomia',
#  'samoka']

# %%
rivers = []
for k in flood_df['tender/title']:
    words = k.replace(',', ' ').replace('_', ' ').\
        replace('.', ' ').replace('ofriver', 'river').\
        replace('Riverbank','river').replace('-',' ').replace('RIVER','river').replace('River','river').split()
    try:
        idx = words.index('river')
    except:
        rivers.append(np.NaN)
        continue
    prefix = words[idx-1]
    try:
        suffix = words[idx+1]
    except:
        suffix = None

    scores_p = []
    scores_s = []
    l =list(dataframeq.id)
    
    for j in list(dataframeq.river_name):
        scores_p.append(fuzz.ratio(j,prefix))
        scores_s.append(fuzz.ratio(j,suffix))
    
    if max(scores_p)>=max(scores_s):
        river = l[scores_p.index(max(scores_p))]
    elif max(scores_p)<max(scores_s):
        river = l[scores_s.index(max(scores_s))]
    else:
        river = np.NaN
        
    rivers.append(river)

# %%
flood_df['river'] = rivers

# %%
flood_df['river'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34740/1506814611.py in <module>
# ----> 1 flood_df['river'].astype('int')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, align_keys, ignore_failures, **kwargs)
#     325                     applied = b.apply(f, **kwargs)
#     326                 else:
# --> 327                     applied = getattr(b, f)(**kwargs)
#     328             except (TypeError, NotImplementedError):
#     329                 if not ignore_failures:
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors)
#     589         values = self.values
#     590
# --> 591         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     592
#     593         new_values = maybe_coerce_values(new_values)
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array_safe(values, dtype, copy, errors)
#    1307
#    1308     try:
# -> 1309         new_values = astype_array(values, dtype, copy=copy)
#    1310     except (ValueError, TypeError):
#    1311         # e.g. astype_nansafe can fail on object-dtype of strings
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_array(values, dtype, copy)
#    1255
#    1256     else:
# -> 1257         values = astype_nansafe(values, dtype, copy=copy)
#    1258
#    1259     # in pandas we don't store numpy str dtypes, so convert to object
#
# ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#    1172         # work around NumPy brokenness, #1987
#    1173         if np.issubdtype(dtype.type, np.integer):
# -> 1174             return lib.astype_intsafe(arr, dtype)
#    1175
#    1176         # if we have a datetime/timedelta array of objects
#
# ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.astype_intsafe()
#
# ValueError: invalid literal for int() with base 10: 'NA'
